# %%
import nltk
import openpyxl
import pymorphy3
import json
import numpy as np
import pandas as pd
import datetime
import sklearn

# %%
def getDateOnly(date):
  return datetime.date(date.year, date.month, date.day)
def getDateOnlyFromString(date_string):
  return getDateOnly(datetime.datetime.strptime(str(date_string), '%Y-%m-%d').date())
def getDateDiffs(dates):
  dates.values.tolist()
  result = []
  for i in range(1, len(dates)):
    result.append((getDateOnly(dates[i]) - getDateOnly(dates[i-1])).days)
  df = pd.DataFrame(result, columns=['DATE_DIFF'])
  return df.groupby(['DATE_DIFF'])['DATE_DIFF'].count()

# %%
market_path = 'market_data/sber_FULL.csv'

# %%
sber = pd.read_csv(market_path) 
sber['DATE'] = sber['DATE'].apply(lambda x: getDateOnlyFromString(x))
sber
# Out:
#      TICKER        DATE         OPEN         HIGH          MID          LOW
# 0      SBER  2000-04-03  1422.000000  1422.000000  1396.000000  1370.000000  \
# 1      SBER  2000-04-04  1390.000000  1546.000000  1460.500000  1375.000000
# 2      SBER  2000-04-05  1475.100000  1510.000000  1448.750000  1387.500000
# 3      SBER  2000-04-06  1410.000000  1462.990000  1436.495000  1410.000000
# 4      SBER  2000-04-07  1416.000000  1430.000000  1407.500000  1385.000000
# ...     ...         ...          ...          ...          ...          ...
# 8404   SBER  2023-04-07   214.500000   216.390000   215.020000   213.650000
# 8405   SBER  2023-04-08   215.366667   218.346667   216.491667   214.636667
# 8406   SBER  2023-04-09   216.233333   220.303333   217.963333   215.623333
# 8407   SBER  2023-04-10   217.100000   222.260000   219.435000   216.610000
# 8408   SBER  2023-04-11   222.900000   223.330000   220.475000   217.620000
#
#         CLOSE       VOL
# 0     1385.00     16938
# 1     1521.00     84058
# 2     1398.00     48853
# 3     1425.01     23364
# 4     1416.00     19315
# ...       ...       ...
# 8404   216.27  29157060
# 8405   218.25  47757683
# 8406   220.23  66358306
# 8407   222.21  84958930
# 8408   218.60  98349200
#
# [8409 rows x 8 columns]

# %%
sber_Y = pd.read_csv('market_data/sber_Y.csv')
sber_Y
# Out:
#             DATE         Y
# 0     2000-04-04  0.046203
# 1     2000-04-05 -0.008045
# 2     2000-04-06 -0.008459
# 3     2000-04-07 -0.020185
# 4     2000-04-08  0.015986
# ...          ...       ...
# 8403  2023-04-07 -0.003268
# 8404  2023-04-08  0.006844
# 8405  2023-04-09  0.006798
# 8406  2023-04-10  0.006752
# 8407  2023-04-11  0.004739
#
# [8408 rows x 2 columns]

# %%
sber_Y['Y'] = sber_Y['Y'].apply(lambda x: x>0)

# %%
#sber_Y['Y'] = sber_Y['Y'].apply(lambda x: x*100)

# %%
sber_no_Date = sber.drop(['DATE', 'TICKER'], axis=1).drop(index=[0]).reset_index(drop=True)
sber_no_Date
# Out:
#              OPEN         HIGH          MID          LOW        CLOSE
# 0     1390.000000  1546.000000  1460.500000  1375.000000  1521.000000  \
# 1     1475.100000  1510.000000  1448.750000  1387.500000  1398.000000
# 2     1410.000000  1462.990000  1436.495000  1410.000000  1425.010000
# 3     1416.000000  1430.000000  1407.500000  1385.000000  1416.000000
# 4     1410.666667  1470.000000  1430.000000  1390.000000  1460.666667
# ...           ...          ...          ...          ...          ...
# 8403   214.500000   216.390000   215.020000   213.650000   216.270000
# 8404   215.366667   218.346667   216.491667   214.636667   218.250000
# 8405   216.233333   220.303333   217.963333   215.623333   220.230000
# 8406   217.100000   222.260000   219.435000   216.610000   222.210000
# 8407   222.900000   223.330000   220.475000   217.620000   218.600000
#
#            VOL
# 0        84058
# 1        48853
# 2        23364
# 3        19315
# 4        26589
# ...        ...
# 8403  29157060
# 8404  47757683
# 8405  66358306
# 8406  84958930
# 8407  98349200
#
# [8408 rows x 6 columns]

# %%
start = 4000
end = 6000

# %%
dataset_X = sber_no_Date.iloc[start:end]
dataset_Y = sber_Y['Y'].iloc[start:end]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(dataset_X, 
                                                    dataset_Y, 
                                                    test_size=0.2, 
                                                    random_state=777)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, SVR
from xgboost import XGBClassifier
from sklearn import metrics

# %%
models = [LogisticRegression(), SVR(), SVC(), XGBClassifier()]
 
for i in range(3):
  models[i].fit(X_train, y_train)

  print(f'{models[i]} : ')
  print('Training Accuracy : ', metrics.roc_auc_score(
    y_train, models[i].predict(X_train)))
  print('Validation Accuracy : ', metrics.roc_auc_score(
    y_test, models[i].predict(X_test)))
  print()
# Out:
# LogisticRegression() :
# Training Accuracy :  0.5
# Validation Accuracy :  0.5
#
# SVR() :
# Training Accuracy :  0.5398812901450811
# Validation Accuracy :  0.47002200220022006
#
# SVC() :
# Training Accuracy :  0.5096770260320675
# Validation Accuracy :  0.47174717471747185

# %%
from keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
import tensorflow as tf

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Conv1D, MaxPooling1D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Dense, Dropout, Activation, Input, Reshape
from tensorflow.keras.layers import LSTM
from keras.layers import LeakyReLU

# %%
X_train.shape
# Out:
# (1600, 6)

# %%
# from keras.layers import LeakyReLU
# model = Sequential()
# model.add(Dense(6, kernel_initializer ='glorot_uniform',input_dim=X_train.shape[1]))
# model.add(LeakyReLU(alpha=0.01))
# model.add(Dropout(0.20))
# model.add(Dense(8, kernel_initializer ='glorot_uniform'))
# model.add(LeakyReLU(alpha=0.01))
# model.add(Dropout(0.20))
# # model.add(LSTM(4))
# model.add(Dropout(0.20))
# model.add(Dense(4))

# model.add(Dense(1, kernel_initializer ='glorot_uniform', activation = 'sigmoid'))
# model.compile(loss='binary_crossentropy',
#               optimizer='adamax',
#               metrics=['accuracy',f1_m,precision_m, recall_m])

# %%
from keras.layers import LeakyReLU
model = Sequential()
#model.add(Dense(6,input_dim=X_train.shape[1], activation='relu'))
model.add(Input(shape=(X_train.shape[1],)))
#model.add(Reshape((1,X_train.shape[1])))
#model.add(LSTM(2, input_shape=(1, X_train.shape[1]), return_sequences=False))
model.add(Dense(6, activation='relu'))
model.add(Dense(1, activation = 'sigmoid'))
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy',f1_m,precision_m, recall_m])
es = tf.keras.callbacks.EarlyStopping(monitor='val_f1_m', min_delta=0, patience=3, verbose=0, mode='auto', baseline=None, restore_best_weights=False)

# %%
# model = Sequential()
# model.add(Dense(6, kernel_initializer ='glorot_uniform',input_dim=X_train.shape[1]))
# model.add(LeakyReLU(alpha=0.01))
# model.add(Dropout(0.20))
# model.add(Dense(1, kernel_initializer ='glorot_uniform'))
# model.add(LeakyReLU(alpha=0.01))
# model.add(Dropout(0.20))
# model.add(Dense(1, kernel_initializer ='glorot_uniform', activation = 'sigmoid'))
# model.compile(loss='binary_crossentropy',
#               optimizer='adamax',
#               metrics=['acc',f1_m,precision_m, recall_m])

#es = tf.keras.callbacks.EarlyStopping(monitor='val_f1_m', min_delta=0, patience=3, verbose=0, mode='auto', baseline=None, restore_best_weights=False)

# %%
model.summary()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_53 (Dense)            (None, 6)                 42
#
#  dense_54 (Dense)            (None, 1)                 7
#
# =================================================================
# Total params: 49
# Trainable params: 49
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, batch_size = 4, epochs = 40, callbacks=[es])
# Out:
# Epoch 1/40
# 361/400 [==========================>...] - ETA: 0s - loss: 19924186.0000 - accuracy: 0.4958 - f1_m: 0.0000e+00 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 1s 563us/step - loss: 18779044.0000 - accuracy: 0.4894 - f1_m: 0.0000e+00 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00
# Epoch 2/40
# 310/400 [======================>.......] - ETA: 0s - loss: 2717894.5000 - accuracy: 0.4976 - f1_m: 0.0000e+00 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 493us/step - loss: 2202600.2500 - accuracy: 0.4894 - f1_m: 0.0000e+00 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00
# Epoch 3/40
# 317/400 [======================>.......] - ETA: 0s - loss: 4762.1211 - accuracy: 0.5063 - f1_m: 0.5907 - precision_m: 0.4692 - recall_m: 0.8833WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 483us/step - loss: 3774.1348 - accuracy: 0.5094 - f1_m: 0.6029 - precision_m: 0.4800 - recall_m: 0.8950
# Epoch 4/40
# 317/400 [======================>.......] - ETA: 0s - loss: 0.7263 - accuracy: 0.5181 - f1_m: 0.6439 - precision_m: 0.5181 - recall_m: 0.9558WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 479us/step - loss: 0.7288 - accuracy: 0.5106 - f1_m: 0.6367 - precision_m: 0.5106 - recall_m: 0.9525
# Epoch 5/40
# 317/400 [======================>.......] - ETA: 0s - loss: 0.7164 - accuracy: 0.5103 - f1_m: 0.6335 - precision_m: 0.5103 - recall_m: 0.9369WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 484us/step - loss: 0.7151 - accuracy: 0.5106 - f1_m: 0.6348 - precision_m: 0.5106 - recall_m: 0.9400
# Epoch 6/40
# 317/400 [======================>.......] - ETA: 0s - loss: 0.7024 - accuracy: 0.5229 - f1_m: 0.6473 - precision_m: 0.5229 - recall_m: 0.9401WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 484us/step - loss: 0.7059 - accuracy: 0.5106 - f1_m: 0.6347 - precision_m: 0.5106 - recall_m: 0.9300
# Epoch 7/40
# 367/400 [==========================>...] - ETA: 0s - loss: 0.6997 - accuracy: 0.5123 - f1_m: 0.6414 - precision_m: 0.5123 - recall_m: 0.9591WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 551us/step - loss: 0.7000 - accuracy: 0.5106 - f1_m: 0.6407 - precision_m: 0.5106 - recall_m: 0.9600
# Epoch 8/40
# 332/400 [=======================>......] - ETA: 0s - loss: 0.6974 - accuracy: 0.5075 - f1_m: 0.6277 - precision_m: 0.5075 - recall_m: 0.9217WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 467us/step - loss: 0.6966 - accuracy: 0.5106 - f1_m: 0.6321 - precision_m: 0.5106 - recall_m: 0.9275
# Epoch 9/40
# 329/400 [=======================>......] - ETA: 0s - loss: 0.6951 - accuracy: 0.5091 - f1_m: 0.6391 - precision_m: 0.5091 - recall_m: 0.9514WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 470us/step - loss: 0.6948 - accuracy: 0.5106 - f1_m: 0.6398 - precision_m: 0.5106 - recall_m: 0.9475
# Epoch 10/40
# 329/400 [=======================>......] - ETA: 0s - loss: 0.6953 - accuracy: 0.4992 - f1_m: 0.6301 - precision_m: 0.4992 - recall_m: 0.9574WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 469us/step - loss: 0.6939 - accuracy: 0.5106 - f1_m: 0.6405 - precision_m: 0.5106 - recall_m: 0.9575
# Epoch 11/40
# 329/400 [=======================>......] - ETA: 0s - loss: 0.6929 - accuracy: 0.5167 - f1_m: 0.6377 - precision_m: 0.5167 - recall_m: 0.9210WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 479us/step - loss: 0.6935 - accuracy: 0.5106 - f1_m: 0.6341 - precision_m: 0.5106 - recall_m: 0.9275
# Epoch 12/40
# 294/400 [=====================>........] - ETA: 0s - loss: 0.6944 - accuracy: 0.4949 - f1_m: 0.6212 - precision_m: 0.4949 - recall_m: 0.9388WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 506us/step - loss: 0.6933 - accuracy: 0.5106 - f1_m: 0.6370 - precision_m: 0.5106 - recall_m: 0.9475
# Epoch 13/40
# 331/400 [=======================>......] - ETA: 0s - loss: 0.6924 - accuracy: 0.5204 - f1_m: 0.6474 - precision_m: 0.5204 - recall_m: 0.9607WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 466us/step - loss: 0.6931 - accuracy: 0.5106 - f1_m: 0.6383 - precision_m: 0.5106 - recall_m: 0.9525
# Epoch 14/40
# 325/400 [=======================>......] - ETA: 0s - loss: 0.6926 - accuracy: 0.5177 - f1_m: 0.6452 - precision_m: 0.5177 - recall_m: 0.9477WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 472us/step - loss: 0.6931 - accuracy: 0.5106 - f1_m: 0.6389 - precision_m: 0.5106 - recall_m: 0.9450
# Epoch 15/40
# 328/400 [=======================>......] - ETA: 0s - loss: 0.6926 - accuracy: 0.5191 - f1_m: 0.6456 - precision_m: 0.5191 - recall_m: 0.9451WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 466us/step - loss: 0.6931 - accuracy: 0.5106 - f1_m: 0.6375 - precision_m: 0.5106 - recall_m: 0.9450
# Epoch 16/40
# 323/400 [=======================>......] - ETA: 0s - loss: 0.6928 - accuracy: 0.5155 - f1_m: 0.6407 - precision_m: 0.5155 - recall_m: 0.9381WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 476us/step - loss: 0.6930 - accuracy: 0.5106 - f1_m: 0.6376 - precision_m: 0.5106 - recall_m: 0.9425
# Epoch 17/40
# 324/400 [=======================>......] - ETA: 0s - loss: 0.6932 - accuracy: 0.5054 - f1_m: 0.6312 - precision_m: 0.5054 - recall_m: 0.9444WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 479us/step - loss: 0.6930 - accuracy: 0.5106 - f1_m: 0.6375 - precision_m: 0.5106 - recall_m: 0.9525
# Epoch 18/40
# 319/400 [======================>.......] - ETA: 0s - loss: 0.6929 - accuracy: 0.5141 - f1_m: 0.6451 - precision_m: 0.5141 - recall_m: 0.9592WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 479us/step - loss: 0.6930 - accuracy: 0.5106 - f1_m: 0.6431 - precision_m: 0.5106 - recall_m: 0.9600
# Epoch 19/40
# 325/400 [=======================>......] - ETA: 0s - loss: 0.6930 - accuracy: 0.5100 - f1_m: 0.6405 - precision_m: 0.5100 - recall_m: 0.9569WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 476us/step - loss: 0.6930 - accuracy: 0.5106 - f1_m: 0.6402 - precision_m: 0.5106 - recall_m: 0.9575
# Epoch 20/40
# 319/400 [======================>.......] - ETA: 0s - loss: 0.6924 - accuracy: 0.5235 - f1_m: 0.6417 - precision_m: 0.5235 - recall_m: 0.9310WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 478us/step - loss: 0.6930 - accuracy: 0.5106 - f1_m: 0.6307 - precision_m: 0.5106 - recall_m: 0.9300
# Epoch 21/40
# 323/400 [=======================>......] - ETA: 0s - loss: 0.6934 - accuracy: 0.5008 - f1_m: 0.6287 - precision_m: 0.5008 - recall_m: 0.9443WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 471us/step - loss: 0.6930 - accuracy: 0.5106 - f1_m: 0.6356 - precision_m: 0.5106 - recall_m: 0.9425
# Epoch 22/40
# 323/400 [=======================>......] - ETA: 0s - loss: 0.6932 - accuracy: 0.5077 - f1_m: 0.6360 - precision_m: 0.5077 - recall_m: 0.9350WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 471us/step - loss: 0.6930 - accuracy: 0.5106 - f1_m: 0.6378 - precision_m: 0.5106 - recall_m: 0.9350
# Epoch 23/40
# 322/400 [=======================>......] - ETA: 0s - loss: 0.6931 - accuracy: 0.5085 - f1_m: 0.6362 - precision_m: 0.5085 - recall_m: 0.9410WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 481us/step - loss: 0.6931 - accuracy: 0.5106 - f1_m: 0.6363 - precision_m: 0.5106 - recall_m: 0.9450
# Epoch 24/40
# 315/400 [======================>.......] - ETA: 0s - loss: 0.6926 - accuracy: 0.5206 - f1_m: 0.6477 - precision_m: 0.5206 - recall_m: 0.9556WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 488us/step - loss: 0.6930 - accuracy: 0.5106 - f1_m: 0.6380 - precision_m: 0.5106 - recall_m: 0.9475
# Epoch 25/40
# 320/400 [=======================>......] - ETA: 0s - loss: 0.6934 - accuracy: 0.5000 - f1_m: 0.6285 - precision_m: 0.5000 - recall_m: 0.9438WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 479us/step - loss: 0.6930 - accuracy: 0.5106 - f1_m: 0.6375 - precision_m: 0.5106 - recall_m: 0.9450
# Epoch 26/40
# 324/400 [=======================>......] - ETA: 0s - loss: 0.6928 - accuracy: 0.5154 - f1_m: 0.6394 - precision_m: 0.5154 - recall_m: 0.9290WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 471us/step - loss: 0.6930 - accuracy: 0.5106 - f1_m: 0.6347 - precision_m: 0.5106 - recall_m: 0.9300
# Epoch 27/40
# 331/400 [=======================>......] - ETA: 0s - loss: 0.6927 - accuracy: 0.5174 - f1_m: 0.6431 - precision_m: 0.5174 - recall_m: 0.9517WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 471us/step - loss: 0.6930 - accuracy: 0.5106 - f1_m: 0.6367 - precision_m: 0.5106 - recall_m: 0.9450
# Epoch 28/40
# 325/400 [=======================>......] - ETA: 0s - loss: 0.6928 - accuracy: 0.5162 - f1_m: 0.6400 - precision_m: 0.5162 - recall_m: 0.9446WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 471us/step - loss: 0.6931 - accuracy: 0.5106 - f1_m: 0.6345 - precision_m: 0.5106 - recall_m: 0.9425
# Epoch 29/40
# 322/400 [=======================>......] - ETA: 0s - loss: 0.6929 - accuracy: 0.5124 - f1_m: 0.6385 - precision_m: 0.5124 - recall_m: 0.9410WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 481us/step - loss: 0.6930 - accuracy: 0.5106 - f1_m: 0.6366 - precision_m: 0.5106 - recall_m: 0.9400
# Epoch 30/40
# 327/400 [=======================>......] - ETA: 0s - loss: 0.6928 - accuracy: 0.5153 - f1_m: 0.6410 - precision_m: 0.5153 - recall_m: 0.9388WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 471us/step - loss: 0.6930 - accuracy: 0.5106 - f1_m: 0.6373 - precision_m: 0.5106 - recall_m: 0.9425
# Epoch 31/40
# 316/400 [======================>.......] - ETA: 0s - loss: 0.6931 - accuracy: 0.5103 - f1_m: 0.6363 - precision_m: 0.5103 - recall_m: 0.9462WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 484us/step - loss: 0.6930 - accuracy: 0.5106 - f1_m: 0.6358 - precision_m: 0.5106 - recall_m: 0.9450
# Epoch 32/40
# 399/400 [============================>.] - ETA: 0s - loss: 0.6930 - accuracy: 0.5107 - f1_m: 0.6406 - precision_m: 0.5107 - recall_m: 0.9499WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 514us/step - loss: 0.6930 - accuracy: 0.5106 - f1_m: 0.6407 - precision_m: 0.5106 - recall_m: 0.9500
# Epoch 33/40
# 358/400 [=========================>....] - ETA: 0s - loss: 0.6930 - accuracy: 0.5105 - f1_m: 0.6358 - precision_m: 0.5105 - recall_m: 0.9441WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 564us/step - loss: 0.6930 - accuracy: 0.5106 - f1_m: 0.6349 - precision_m: 0.5106 - recall_m: 0.9425
# Epoch 34/40
# 321/400 [=======================>......] - ETA: 0s - loss: 0.6934 - accuracy: 0.5008 - f1_m: 0.6277 - precision_m: 0.5008 - recall_m: 0.9252WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 476us/step - loss: 0.6931 - accuracy: 0.5106 - f1_m: 0.6351 - precision_m: 0.5106 - recall_m: 0.9250
# Epoch 35/40
# 326/400 [=======================>......] - ETA: 0s - loss: 0.6930 - accuracy: 0.5100 - f1_m: 0.6346 - precision_m: 0.5100 - recall_m: 0.9387WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 476us/step - loss: 0.6930 - accuracy: 0.5106 - f1_m: 0.6329 - precision_m: 0.5106 - recall_m: 0.9300
# Epoch 36/40
# 331/400 [=======================>......] - ETA: 0s - loss: 0.6931 - accuracy: 0.5091 - f1_m: 0.6384 - precision_m: 0.5091 - recall_m: 0.9547WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 469us/step - loss: 0.6931 - accuracy: 0.5106 - f1_m: 0.6408 - precision_m: 0.5106 - recall_m: 0.9575
# Epoch 37/40
# 325/400 [=======================>......] - ETA: 0s - loss: 0.6928 - accuracy: 0.5162 - f1_m: 0.6436 - precision_m: 0.5162 - recall_m: 0.9569WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 476us/step - loss: 0.6930 - accuracy: 0.5106 - f1_m: 0.6371 - precision_m: 0.5106 - recall_m: 0.9475
# Epoch 38/40
# 315/400 [======================>.......] - ETA: 0s - loss: 0.6929 - accuracy: 0.5135 - f1_m: 0.6412 - precision_m: 0.5135 - recall_m: 0.9556WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 486us/step - loss: 0.6930 - accuracy: 0.5106 - f1_m: 0.6365 - precision_m: 0.5106 - recall_m: 0.9475
# Epoch 39/40
# 325/400 [=======================>......] - ETA: 0s - loss: 0.6931 - accuracy: 0.5077 - f1_m: 0.6338 - precision_m: 0.5077 - recall_m: 0.9385WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 476us/step - loss: 0.6930 - accuracy: 0.5106 - f1_m: 0.6364 - precision_m: 0.5106 - recall_m: 0.9400
# Epoch 40/40
# 329/400 [=======================>......] - ETA: 0s - loss: 0.6930 - accuracy: 0.5106 - f1_m: 0.6350 - precision_m: 0.5106 - recall_m: 0.9331WARNING:tensorflow:Early stopping conditioned on metric `val_f1_m` which is not available. Available metrics are: loss,accuracy,f1_m,precision_m,recall_m
# 400/400 [==============================] - 0s 469us/step - loss: 0.6930 - accuracy: 0.5106 - f1_m: 0.6345 - precision_m: 0.5106 - recall_m: 0.9300

# %%
y_pred = model.predict(X_test)
# Out:
# 13/13 [==============================] - 0s 500us/step

# %%
y_pred = np.array([i>0.5 for i in y_pred.flatten()])
y_pred
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True])

# %%
from sklearn.metrics import f1_score, precision_score,recall_score, precision_recall_curve

# %%
f1_score(y_test, y_pred)
# Out:
# 0.6622073578595317

# %%
precision_score(y_test, y_pred)
# Out:
# 0.495

# %%
recall_score(y_test, y_pred)
# Out:
# 1.0
